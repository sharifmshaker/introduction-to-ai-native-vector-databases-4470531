# %% [markdown]
# Given 3D vectors [40,120,60] and [60,50,90]

# %% [markdown]
# ### Q1 draw out these vectors

# %%
# %config IPCompleter.greedy=True

# %%
import numpy as np
import matplotlib.pyplot as plt

#Initialize the two vectors

# ADD CODE HERE
colour1 = [40,120,60]
colour2 = [60,50,90]

ax = plt.figure().add_subplot(projection='3d') 
# Draw out the vectors

xs = np.array([colour1[0], colour2[0]])
ys = np.array([colour1[1], colour2[1]])
zs = np.array([colour1[2], colour2[2]])
ax.scatter(xs, ys, zs)


# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 150)
ax.set_ylim(0, 150)
ax.set_zlim(0, 150)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# -----

# %% [markdown]
# ### Q2 Calculate the euclidian, manhattan, cosine, and dot product distances between these vectors

# %% [markdown]
# ### Manhattan distance

# %%
L1 = abs(colour2[0] - colour1[0]) + abs(colour2[1] - colour1[1]) + abs(colour2[2] - colour1[2]) 

print(L1)
# Out:
# 120

# %%
#An alternate approach

a = np.array(colour1)
b = np.array(colour2)

np.linalg.norm((a - b), ord=1)
# Out:
# 120.0

# %% [markdown]
# ### Euclidian distance

# %%
L2 = math.sqrt((colour2[0] - colour1[0])**2 + (colour2[1] - colour1[1])**2 + (colour2[2] - colour1[2])**2)

print(L2)
# Out:
# 78.74007874011811

# %%
np.linalg.norm((a - b), ord=2)
# Out:
# 78.74007874011811

# %% [markdown]
# ### Cosine distance

# %%
cosine = 1 - np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

print(cosine)
# Out:
# 0.17280694682183517

# %% [markdown]
# ### Dot product

# %%
dot = a[0]*b[0] + a[1]*b[1] + a[2]*b[2]

print(dot)
# Out:
# 13800

# %%
#alternate method

np.dot(a,b)
# Out:
# 13800

# %% [markdown]
# ---

# %% [markdown]
# ### Q3 Can you come up with a colour that has a smaller cosine distance from the first vector?

# %%
colour1 = [40,120,60]
colour2 = [60,50,90]

colour3 = [50,130,60]

# %%
ax = plt.figure().add_subplot(projection='3d')

# Plot a sin curve using the x and y axes.
ax.scatter(xs=colour1[0], ys=colour1[1], zs=colour1[2], zdir='z', label='Colour1')

ax.scatter(xs=colour2[0], ys=colour2[1], zs=colour2[2], zdir='z', label='Colour2')

ax.scatter(0, 0, 0, zdir='z', label='Origin', c='black')

ax.quiver(0,0,0,colour1[0],colour1[1],colour1[2], color='black', arrow_length_ratio=0.1)
ax.quiver(0,0,0,colour2[0],colour2[1],colour2[2], color='black', arrow_length_ratio=0.1)

#Add vector 3 to the diagram

ax.scatter(xs=colour3[0], ys=colour3[1], zs=colour3[2], zdir='z', label='Colour2')
ax.quiver(0,0,0,colour3[0],colour3[1],colour3[2], color='black', arrow_length_ratio=0.1)

# Make legend, set axes limits and labels
ax.legend()
ax.set_xlim(0, 150)
ax.set_ylim(0, 150)
ax.set_zlim(0, 150)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Customize the view angle so it's easier to see that the scatter points lie
# on the plane y=0
ax.view_init(elev=20., azim=-35, roll=0)

plt.show()
